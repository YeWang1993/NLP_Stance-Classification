# %% [markdown]
# # Environment Set-up, Pre-processing and Hand-crafted Features Extraction

# %%
# Environment Set-up
import os

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

import tensorflow as tf
from keras.backend.tensorflow_backend import set_session
tf_config = tf.ConfigProto()
tf_config.gpu_options.allow_growth = True
sess = tf.Session(config=tf_config)

set_session(sess)
import gensim
import keras
import re
from string import punctuation
import numpy as np
import pandas as pd
import nltk
nltk.download('wordnet')
nltk.download('punkt')
from tqdm import tqdm
from sklearn import feature_extraction
from pandas import DataFrame
from nltk.tokenize import word_tokenize
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Input, Dense, LSTM, Embedding, Dropout, BatchNormalization, Activation, Bidirectional
from keras.preprocessing.text import text_to_word_sequence, Tokenizer
from keras.preprocessing.sequence import pad_sequences
np.random.seed(1003)
import numpy as np
from collections import defaultdict
import nltk
import numpy as np


from keras.models import Model
from keras.layers import Layer, Input, Dense, Concatenate, Conv2D, Reshape, MaxPooling1D, Flatten, BatchNormalization, Activation, Dropout, Embedding
import nltk
_wnl = nltk.WordNetLemmatizer()


# Specify the folder locations
W2V_DIR = '/home/students/y2886wan/W/GoogleNews-vectors-negative300.bin'
DATA_DIR = 'data/'
#EMB_DIR = '/home/students/y2886wan/glove_data/glove.6B.50d.txt'

# Hyperparameters 
MAX_SENT_LEN_1 = 16
MAX_SENT_LEN_2 = 512
LSTM_DIM = 16
MAX_VOCAB_SIZE=26562
EMBEDDING_DIM = 300
BATCH_SIZE = 128
N_EPOCHS = 200


# Loading data
trainData_Heading = pd.read_csv("/home/students/y2886wan/Data/train_data.csv")
valData_Heading = pd.read_csv("/home/students/y2886wan/Data/validation_data.csv")
trainData_Bodies = pd.read_csv("/home/students/y2886wan/Data/article_body_texts.csv")

# Stop word
stop_words = ['the','a','an','and','but','if','or','because','as','what','which','this','that','these','those','then',
              'just','so','than','such','both','through','about','for','is','of','while','during','to','What','Which',
              'Is','If','While','This']

# Data generater
def generate_data(Heading,Bodies):

    Data = pd.merge(Heading, Bodies, how='left', on='Body ID')

    Data = Data.sample(frac=1, random_state=10) # Shuffle the rows
    Data.reset_index(inplace=True, drop=True)

    Data['Headline'] = Data['Headline'].apply(lambda x: str(x))
    Data['articleBody'] = Data['articleBody'].apply(lambda x: str(x))
    
    return Data

def normalize_word(w):
    return _wnl.lemmatize(w).lower()

# Cleaning data
def text_to_wordlist(text, remove_stop_words=True, stem_words=False):
    text = re.sub(r"[^A-Za-z0-9]", " ", text)
    text = re.sub(r"what's", "", text)
    text = re.sub(r"What's", "", text)
    text = re.sub(r"\'s", " ", text)
    text = re.sub(r"\'ve", " have ", text)
    text = re.sub(r"can't", "cannot ", text)
    text = re.sub(r"n't", " not ", text)
    text = re.sub(r"I'm", "I am", text)
    text = re.sub(r" m ", " am ", text)
    text = re.sub(r"\'re", " are ", text)
    text = re.sub(r"\'d", " would ", text)
    text = re.sub(r"\'ll", " will ", text)
    text = re.sub(r"60k", " 60000 ", text)
    text = re.sub(r" e g ", " eg ", text)
    text = re.sub(r" b g ", " bg ", text)
    text = re.sub(r"\0s", "0", text)
    text = re.sub(r" 9 11 ", "911", text)
    text = re.sub(r"e-mail", "email", text)
    text = re.sub(r"\s{2,}", " ", text)
    text = re.sub(r"quikly", "quickly", text)
    text = re.sub(r" usa ", " America ", text)
    text = re.sub(r" USA ", " America ", text)
    text = re.sub(r" u s ", " America ", text)
    text = re.sub(r" U S ", " America ", text)
    text = re.sub(r" uk ", " England ", text)
    text = re.sub(r" UK ", " England ", text)
    text = re.sub(r"india", "India", text)
    text = re.sub(r"switzerland", "Switzerland", text)
    text = re.sub(r"china", "China", text)
    text = re.sub(r"chinese", "Chinese", text) 
    text = re.sub(r"imrovement", "improvement", text)
    text = re.sub(r"intially", "initially", text)
    text = re.sub(r"quora", "Quora", text)
    text = re.sub(r" dms ", "direct messages ", text)  
    text = re.sub(r"demonitization", "demonetization", text) 
    text = re.sub(r"actived", "active", text)
    text = re.sub(r"kms", " kilometers ", text)
    text = re.sub(r"KMs", " kilometers ", text)
    text = re.sub(r" cs ", " computer science ", text) 
    text = re.sub(r" upvotes ", " up votes ", text)
    text = re.sub(r" iPhone ", " phone ", text)
    text = re.sub(r"\0rs ", " rs ", text) 
    text = re.sub(r"calender", "calendar", text)
    text = re.sub(r"ios", "operating system", text)
    text = re.sub(r"gps", "GPS", text)
    text = re.sub(r"gst", "GST", text)
    text = re.sub(r"programing", "programming", text)
    text = re.sub(r"bestfriend", "best friend", text)
    text = re.sub(r"dna", "DNA", text)
    text = re.sub(r"III", "3", text) 
    text = re.sub(r"the US", "America", text)
    text = re.sub(r"Astrology", "astrology", text)
    text = re.sub(r"Method", "method", text)
    text = re.sub(r"Find", "find", text) 
    text = re.sub(r"banglore", "Banglore", text)
    text = re.sub(r" J K ", " JK ", text)
    
    # Remove punctuation from text
    text = ''.join([c for c in text if c not in punctuation])
    
    # Optionally, remove stop words
    if remove_stop_words:
        text = text.split()
        text = [w for w in text if not w in stop_words]
        text = " ".join(text)
    
    # Optionally, shorten words to their stems
    if stem_words:
        text = text.split()
        stemmer = SnowballStemmer('english')
        stemmed_words = [stemmer.stem(word) for word in text]
        text = " ".join(stemmed_words)
    
    # Return a list of words
    return(text)


# Processing headline and bodies
def process_questions(question_list, questions, question_list_name, dataframe):
    for question in questions:
        question_list.append(text_to_wordlist(question))
        if len(question_list) % 100000 == 0:
            progress = len(question_list)/len(dataframe) * 100
            print("{} is {}% complete.".format(question_list_name, round(progress, 1)))


            
# Overlap features extraction
def get_pairwise_word_to_doc_freq(headlines, bodies):
    """
    Get pairwise word to document frequency.
    For index i, if sentence i in headlines and sentence i in bodies both
    container word w, then w is counted only once.
    Returns a dictionary mapping words to number of sentence pairs the word appears in.
    """
    word_to_doc_cnt = defaultdict(int)

    for s1, s2 in zip(headlines, bodies):
        unique_tokens = set(s1) | set(s2)
        for t in unique_tokens:
            word_to_doc_cnt[t] += 1

    return word_to_doc_cnt

def get_pairwise_overlap_features(headlines, bodies, word_to_doc_cnt):
    """
    Get overlap, idf weighted overlap, overlap excluding stopwords, and idf weighted overlap excluding stopwords.
    """
    stoplist = set(stop_words)
    num_docs = len(headlines)
    overlap_feats = []

    for s1, s2 in zip(headlines, bodies):
        tokens_a_set, tokens_b_set = set(s1), set(s2)
        intersect = tokens_a_set & tokens_b_set
        overlap = len(intersect) / len(tokens_a_set) 
        idf_intersect = sum(np.math.log(num_docs / word_to_doc_cnt[w]) for w in intersect)
        idf_weighted_overlap = idf_intersect / (len(tokens_a_set) + len(tokens_b_set))

        tokens_a_set_no_stop = set(w for w in s1 if w not in stoplist)
        tokens_b_set_no_stop = set(w for w in s2 if w not in stoplist)
        intersect_no_stop = tokens_a_set_no_stop & tokens_b_set_no_stop
        overlap_no_stop = len(intersect_no_stop) / (len(tokens_a_set_no_stop) + len(tokens_b_set_no_stop))
        idf_intersect_no_stop = sum(np.math.log(num_docs / word_to_doc_cnt[w]) for w in intersect_no_stop)
        idf_weighted_overlap_no_stop = idf_intersect_no_stop / (len(tokens_a_set_no_stop) + len(tokens_b_set_no_stop))
        overlap_feats.append([overlap, idf_weighted_overlap, overlap_no_stop, idf_weighted_overlap_no_stop])

    return overlap_feats




# Refuting features extraction
def refuting_features(headlines, bodies):
    _refuting_words = [
        'fake',
        'fraud',
        'hoax',
        'false',
        'deny', 'denies',
        # 'refute',
        'not',
        'despite',
        'nope',
        'doubt', 'doubts',
        'bogus',
        'debunk',
        'pranks',
        'retract'
    ]
    X = []
    for i, (headline, body) in tqdm(enumerate(zip(headlines, bodies))):
        clean_headline = clean(headline)
        clean_headline = get_tokenized_lemmas(clean_headline)
        features = [1 if word in clean_headline else 0 for word in _refuting_words]
        features =list(features)
        X.append(features)
    return X



# Polarity features extraction
def clean(s):
    # Cleans a string: Lowercasing, trimming, removing non-alphanumeric

    return " ".join(re.findall(r'\w+', s, flags=re.UNICODE)).lower()

def get_tokenized_lemmas(s):
    return [normalize_word(t) for t in nltk.word_tokenize(s)]

def polarity_features(headlines, bodies):
    _refuting_words = [
        'fake',
        'fraud',
        'hoax',
        'false',
        'deny', 'denies',
        'not',
        'despite',
        'nope',
        'doubt', 'doubts',
        'bogus',
        'debunk',
        'pranks',
        'retract'
    ]

    def calculate_polarity(text):
        tokens = get_tokenized_lemmas(text)
        return sum([t in _refuting_words for t in tokens]) % 2
    X = []
    for i, (headline, body) in tqdm(enumerate(zip(headlines, bodies))):
        clean_headline = clean(headline)
        clean_body = clean(body)
        features = []
        features.append(calculate_polarity(clean_headline))
        features.append(calculate_polarity(clean_body))
        X.append(features)
    return np.array(X)


# Concatenate training data and validation data
test_count = len(valData_Heading)
trainData = generate_data(trainData_Heading,trainData_Bodies)
valData = generate_data(valData_Heading,trainData_Bodies)
frames=[trainData,valData]
trainData = pd.concat(frames)


# Processing headline and bodies
train_headling = []
process_questions(train_headling, trainData.Headline, 'train_headling', trainData)
train_bodies = []
process_questions(train_bodies, trainData.articleBody, 'train_bodies', trainData)

# Generating hand-crafted features
cnt = get_pairwise_word_to_doc_freq(train_headling, train_bodies)
overlap_features = get_pairwise_overlap_features(train_headling, train_bodies, cnt)
refuting_feature = refuting_features(train_headling, train_bodies)
polarity_feature = polarity_features(train_headling, train_bodies)

word_seq = train_headling + train_bodies
word_seq = [' '.join(word_tokenize(q)[:MAX_SENT_LEN_2]) for q in word_seq]


# Tokenizer, transform words into interger identifier, create a dictionary
tokenizer = Tokenizer(num_words=MAX_VOCAB_SIZE, filters='!"#$%&()*+,-./:;<=>@[\\]^_`{|}~\t\n')
tokenizer.fit_on_texts(word_seq)
print("Number of words in vocabulary:", len(tokenizer.word_index))


# Transform all document into vectors using dictionary
X = tokenizer.texts_to_sequences(word_seq)
X = pad_sequences(X, maxlen=MAX_SENT_LEN_2, padding='post', truncating='post')

# Separate headline and bodies
X_q1 = X[:len(X)//2]
X_q2 = X[len(X)//2:]
del X

# Reducing dimension of headline from 512 to 16
X_q1 = np.delete(X_q1, range(MAX_SENT_LEN_1, MAX_SENT_LEN_2), axis = 1)

# Transform each stance into vector
Stance_list = [' '.join(word_tokenize(x)[:MAX_SENT_LEN_2]) for x in trainData['Stance']]
wordstance=[]
for i in Stance_list:
    if i=='unrelated':
        wordstance.append([0,0,0,1])
    if i=='discuss':
        wordstance.append([0,0,1,0])
    if i=='agree':
        wordstance.append([0,1,0,0])
    if i=='disagree':
        wordstance.append([1,0,0,0])


# unpacked = [x[0] for x in y_stance]
y = np.array(wordstance)

# # Split Train and Test Set 

X_train_q1, X_test_q1, X_train_q2, X_test_q2, overlap_train, overlap_test, refuting_train, refuting_test, polarity_train, polarity_test, y_train, y_test = train_test_split(X_q1, X_q2, overlap_features, refuting_feature, polarity_feature, y, random_state=10, test_size=test_count)

# Transform array to list
polarity_train = [i.tolist() for i in polarity_train]
polarity_test = [i.tolist() for i in polarity_test]

# Concatenate features for train
features_train = [[x+y+z] for x,y,z in zip(overlap_train, refuting_train, polarity_train)]
feature_train = [x[0] for x in features_train]

# Concatenate features for test
features_test = [[x+y+z] for x,y,z in zip(overlap_test, refuting_test, polarity_test)]
feature_test = [x[0] for x in features_test]
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/students/y2886wan/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home/students/y2886wan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 69115it [00:15, 4522.29it/s]
# 69115it [04:00, 287.40it/s]
# Number of words in vocabulary: 26561

# %% [markdown]
# # Embedding Matrix

# %%
# Word2Vec model
embeddings = gensim.models.KeyedVectors.load_word2vec_format(W2V_DIR, binary=True)

# %%
# GloVe embedding
'''
# Load GloVe word embeddings
# Download Link: https://nlp.stanford.edu/projects/glove/
print("[INFO]: Reading Word Embeddings ...")
# Data path
embeddings = {}
f = open(EMB_DIR)
for line in f:
    values = line.split()
    word = values[0]
    vector = np.asarray(values[1:], dtype='float32')
    embeddings[word] = vector
f.close()
'''

# %%
# Words embedding
embeddings_matrix = np.random.uniform(-0.05, 0.05, size=(len(tokenizer.word_index) + 1, EMBEDDING_DIM))  # +1 is because the matrix indices start with 0
for word, i in tokenizer.word_index.items():  # i=0 is the embedding for the zero padding
    try:
        embeddings_vector = embeddings[word]
    except KeyError:
        embeddings_vector = None
    if embeddings_vector is not None:
        embeddings_matrix[i] = embeddings_vector

del embeddings

# %% [markdown]
# # LSTM-CNN Model

# %%
# Bigram and trigram filters
bi_filter_size = 2
tri_filter_size = 3
num_filters = 20

# %%
# LSTM
input_1 = Input(shape=(MAX_SENT_LEN_1, ), name='headline_input') #shape: a vector
# Common embedding lookup layer
emb_look_up = Embedding(input_dim=MAX_VOCAB_SIZE,
                        output_dim=EMBEDDING_DIM,
                        weights = [embeddings_matrix], 
                        trainable=True, 
                        mask_zero=False,
                        name='embedding_lookup')

emb_1 = emb_look_up(input_1)

LSTM_Layer = LSTM(LSTM_DIM, return_sequences=False, name='lstm_layer')
LSTM_Out = LSTM_Layer(emb_1)
Dense_layer = Dense(40, activation='sigmoid', name='headline_output_layer_1')
Dense_Out_1 = Dense_layer(LSTM_Out)

# %%
# CNN
input_2 = Input(shape=(MAX_SENT_LEN_2, ), name='bodies_input')

emb_2 = emb_look_up(input_2)

# Need to be reshaped because the CONV layer assumes 1 dimnesion as num of channels
emb_2 = Reshape((1, MAX_SENT_LEN_2, EMBEDDING_DIM), 
                name='bodies_embedding_reshape')(emb_2)

# Convolutional Layers
conv_2_bi =  Conv2D(filters=num_filters, 
                    kernel_size=(bi_filter_size, EMBEDDING_DIM), 
                    padding='valid', 
                    activation='relu', 
                    data_format='channels_first', 
                    name='bodies_bigram_conv')(emb_2)

conv_2_tri =  Conv2D(filters=num_filters, 
                     kernel_size=(tri_filter_size, EMBEDDING_DIM), 
                     padding='valid', 
                     activation='relu', 
                     data_format='channels_first', 
                     name='bodies_trigram_conv')(emb_2)

# Remove channel dimension before max-pooling operation
bi_out_timesteps_2 = MAX_SENT_LEN_2 - bi_filter_size + 1
tri_out_timesteps_2 = MAX_SENT_LEN_2 - tri_filter_size + 1

# Remove channel dimension before max-pooling operation
conv_2_bi = Reshape((bi_out_timesteps_2, num_filters), 
                    name='bodies_bigram_conv_reshape')(conv_2_bi) # (MAX_SENT_LEN - bi_filter_size + 1, num_filters)
conv_2_tri = Reshape((tri_out_timesteps_2, num_filters), 
                     name='bodies_trigram_conv_reshape')(conv_2_tri)

# Max-pooling Layer
# Pool across timesteps to get 1 feature per filter
max_pool_2_bi = MaxPooling1D(pool_size = bi_out_timesteps_2, 
                             name='bodies_bigram_maxpool')(conv_2_bi)
max_pool_2_tri = MaxPooling1D(pool_size = tri_out_timesteps_2, 
                              name='bodies_trigram_maxpool')(conv_2_tri)

# Merge the features learnt by bi and tri filters
merged_2 = Concatenate(name='bodies_maxpool_flatten')([max_pool_2_bi, max_pool_2_tri])
# Inputs dropped out randomly so that there is no heavy dependence on specific features for prediction
dropout_2 = Dropout(rate=0.2, name='bodies_dropout')(merged_2)
flatten_2 = Flatten(name='bodies_flatten')(dropout_2)

# %%
# With batch-normalization, the output of a previous layer is mu-sigma normalized, 
# before it is fed into the next layer. 
# For feed-forward networks, batch-normalization is carried out 

# Additional features input
input_3 = Input(shape=(21, ), name='feature_input')

# Merge headline, bodies and hand-crafted features
merged = Concatenate(name='headling_bodies_features_concat')([Dense_Out_1, flatten_2, input_3])

# Dense layers
dense_1 = Dense(units=10, name='headling_bodies_features_dense')(merged)
bn_1 = BatchNormalization(name='batchnorm')(dense_1)
relu_1 = Activation(activation='relu', name='relu_activation')(bn_1)
dense_1_dropout = Dropout(0.2, name='dense_dropout')(relu_1)

output_prob = Dense(units=4, activation='softmax', name='output_layer')(dense_1_dropout)

model = Model(inputs=[input_1, input_2, input_3], outputs=output_prob, name='text_pair_cnn')
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# headline_input (InputLayer)     (None, 16)           0
# __________________________________________________________________________________________________
# bodies_input (InputLayer)       (None, 512)          0
# __________________________________________________________________________________________________
# embedding_lookup (Embedding)    multiple             7968600     headline_input[0][0]
#                                                                  bodies_input[0][0]
# __________________________________________________________________________________________________
# bodies_embedding_reshape (Resha (None, 1, 512, 300)  0           embedding_lookup[1][0]
# __________________________________________________________________________________________________
# bodies_bigram_conv (Conv2D)     (None, 20, 511, 1)   12020       bodies_embedding_reshape[0][0]
# __________________________________________________________________________________________________
# bodies_trigram_conv (Conv2D)    (None, 20, 510, 1)   18020       bodies_embedding_reshape[0][0]
# __________________________________________________________________________________________________
# bodies_bigram_conv_reshape (Res (None, 511, 20)      0           bodies_bigram_conv[0][0]
# __________________________________________________________________________________________________
# bodies_trigram_conv_reshape (Re (None, 510, 20)      0           bodies_trigram_conv[0][0]
# __________________________________________________________________________________________________
# bodies_bigram_maxpool (MaxPooli (None, 1, 20)        0           bodies_bigram_conv_reshape[0][0]
# __________________________________________________________________________________________________
# bodies_trigram_maxpool (MaxPool (None, 1, 20)        0           bodies_trigram_conv_reshape[0][0]
# __________________________________________________________________________________________________
# bodies_maxpool_flatten (Concate (None, 1, 40)        0           bodies_bigram_maxpool[0][0]
#                                                                  bodies_trigram_maxpool[0][0]
# __________________________________________________________________________________________________
# lstm_layer (LSTM)               (None, 16)           20288       embedding_lookup[0][0]
# __________________________________________________________________________________________________
# bodies_dropout (Dropout)        (None, 1, 40)        0           bodies_maxpool_flatten[0][0]
# __________________________________________________________________________________________________
# headline_output_layer_1 (Dense) (None, 40)           680         lstm_layer[0][0]
# __________________________________________________________________________________________________
# bodies_flatten (Flatten)        (None, 40)           0           bodies_dropout[0][0]
# __________________________________________________________________________________________________
# feature_input (InputLayer)      (None, 21)           0
# __________________________________________________________________________________________________
# headling_bodies_features_concat (None, 101)          0           headline_output_layer_1[0][0]
#                                                                  bodies_flatten[0][0]
#                                                                  feature_input[0][0]
# __________________________________________________________________________________________________
# headling_bodies_features_dense  (None, 10)           1020        headling_bodies_features_concat[0
# __________________________________________________________________________________________________
# batchnorm (BatchNormalization)  (None, 10)           40          headling_bodies_features_dense[0]
# __________________________________________________________________________________________________
# relu_activation (Activation)    (None, 10)           0           batchnorm[0][0]
# __________________________________________________________________________________________________
# dense_dropout (Dropout)         (None, 10)           0           relu_activation[0][0]
# __________________________________________________________________________________________________
# output_layer (Dense)            (None, 4)            44          dense_dropout[0][0]
# ==================================================================================================
# Total params: 8,020,712
# Trainable params: 8,020,692
# Non-trainable params: 20
# __________________________________________________________________________________________________

# %%
from matplotlib import pyplot as plt
from keras.utils import plot_model 
from IPython.display import Image
plot_model(model, to_file='text_pair_cnn_classifier.png', show_layer_names=True, show_shapes=True)
Image('text_pair_cnn_classifier.png')

# %%
import keras.backend as K


from keras import metrics
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy', metrics.categorical_accuracy])

# %%
# Training LSTM and CNN model
model.fit(x = [X_train_q1, X_train_q2, np.array(feature_train)], 
          y = y_train, 
          batch_size=BATCH_SIZE, 
          epochs=N_EPOCHS, 
          validation_data=([X_test_q1, X_test_q2, np.array(feature_test)], y_test))
# Out:
# Train on 66677 samples, validate on 2438 samples
# Epoch 1/200
# 66677/66677 [==============================] - 310s 5ms/step - loss: 0.3670 - acc: 0.8465 - categorical_accuracy: 0.6828 - val_loss: 0.2561 - val_acc: 0.9028 - val_categorical_accuracy: 0.7998
# Epoch 2/200
# 66677/66677 [==============================] - 308s 5ms/step - loss: 0.2387 - acc: 0.9045 - categorical_accuracy: 0.8001 - val_loss: 0.1978 - val_acc: 0.9232 - val_categorical_accuracy: 0.8347
# Epoch 3/200
# 66677/66677 [==============================] - 308s 5ms/step - loss: 0.2015 - acc: 0.9180 - categorical_accuracy: 0.8267 - val_loss: 0.1751 - val_acc: 0.9304 - val_categorical_accuracy: 0.8519
# Epoch 4/200
# 66677/66677 [==============================] - 308s 5ms/step - loss: 0.1785 - acc: 0.9271 - categorical_accuracy: 0.8458 - val_loss: 0.1593 - val_acc: 0.9368 - val_categorical_accuracy: 0.8642
# Epoch 5/200
# 66677/66677 [==============================] - 308s 5ms/step - loss: 0.1619 - acc: 0.9335 - categorical_accuracy: 0.8601 - val_loss: 0.1559 - val_acc: 0.9363 - val_categorical_accuracy: 0.8663
# Epoch 6/200
# 66677/66677 [==============================] - 308s 5ms/step - loss: 0.1535 - acc: 0.9375 - categorical_accuracy: 0.8693 - val_loss: 0.1465 - val_acc: 0.9387 - val_categorical_accuracy: 0.8753
# Epoch 7/200
# 66677/66677 [==============================] - 308s 5ms/step - loss: 0.1443 - acc: 0.9408 - categorical_accuracy: 0.8773 - val_loss: 0.1350 - val_acc: 0.9450 - val_categorical_accuracy: 0.8852
# Epoch 8/200
# 66677/66677 [==============================] - 307s 5ms/step - loss: 0.1379 - acc: 0.9439 - categorical_accuracy: 0.8847 - val_loss: 0.1264 - val_acc: 0.9497 - val_categorical_accuracy: 0.8991
# Epoch 9/200
# 66677/66677 [==============================] - 308s 5ms/step - loss: 0.1328 - acc: 0.9455 - categorical_accuracy: 0.8862 - val_loss: 0.1224 - val_acc: 0.9509 - val_categorical_accuracy: 0.9020
# Epoch 10/200
# 66677/66677 [==============================] - 308s 5ms/step - loss: 0.1289 - acc: 0.9471 - categorical_accuracy: 0.8902 - val_loss: 0.1220 - val_acc: 0.9510 - val_categorical_accuracy: 0.8979
# Epoch 11/200
# 66677/66677 [==============================] - 308s 5ms/step - loss: 0.1260 - acc: 0.9484 - categorical_accuracy: 0.8918 - val_loss: 0.1115 - val_acc: 0.9532 - val_categorical_accuracy: 0.9053
# Epoch 12/200
# 66677/66677 [==============================] - 307s 5ms/step - loss: 0.1227 - acc: 0.9502 - categorical_accuracy: 0.8962 - val_loss: 0.1187 - val_acc: 0.9529 - val_categorical_accuracy: 0.9065
# Epoch 13/200
# 66677/66677 [==============================] - 308s 5ms/step - loss: 0.1209 - acc: 0.9506 - categorical_accuracy: 0.8972 - val_loss: 0.1157 - val_acc: 0.9543 - val_categorical_accuracy: 0.9040
# Epoch 14/200
# 66677/66677 [==============================] - 308s 5ms/step - loss: 0.1185 - acc: 0.9517 - categorical_accuracy: 0.8997 - val_loss: 0.1172 - val_acc: 0.9530 - val_categorical_accuracy: 0.9069
# Epoch 15/200
# 66677/66677 [==============================] - 308s 5ms/step - loss: 0.1159 - acc: 0.9524 - categorical_accuracy: 0.9007 - val_loss: 0.1131 - val_acc: 0.9545 - val_categorical_accuracy: 0.9094
# Epoch 16/200
# 66677/66677 [==============================] - 308s 5ms/step - loss: 0.1141 - acc: 0.9537 - categorical_accuracy: 0.9034 - val_loss: 0.1142 - val_acc: 0.9537 - val_categorical_accuracy: 0.9040
# Epoch 17/200
# 66677/66677 [==============================] - 308s 5ms/step - loss: 0.1131 - acc: 0.9540 - categorical_accuracy: 0.9035 - val_loss: 0.1144 - val_acc: 0.9548 - val_categorical_accuracy: 0.9118
# Epoch 18/200
# 66677/66677 [==============================] - 308s 5ms/step - loss: 0.1119 - acc: 0.9541 - categorical_accuracy: 0.9041 - val_loss: 0.1141 - val_acc: 0.9546 - val_categorical_accuracy: 0.9089
# Epoch 19/200
# 66677/66677 [==============================] - 308s 5ms/step - loss: 0.1101 - acc: 0.9548 - categorical_accuracy: 0.9069 - val_loss: 0.1062 - val_acc: 0.9563 - val_categorical_accuracy: 0.9114
# Epoch 20/200
# 66677/66677 [==============================] - 307s 5ms/step - loss: 0.1078 - acc: 0.9558 - categorical_accuracy: 0.9099 - val_loss: 0.1057 - val_acc: 0.9584 - val_categorical_accuracy: 0.9163
# Epoch 21/200
# 66677/66677 [==============================] - 307s 5ms/step - loss: 0.1059 - acc: 0.9565 - categorical_accuracy: 0.9110 - val_loss: 0.1053 - val_acc: 0.9593 - val_categorical_accuracy: 0.9151
# Epoch 22/200
# 66677/66677 [==============================] - 307s 5ms/step - loss: 0.1065 - acc: 0.9558 - categorical_accuracy: 0.9094 - val_loss: 0.1064 - val_acc: 0.9566 - val_categorical_accuracy: 0.9110
# Epoch 23/200
# 66677/66677 [==============================] - 307s 5ms/step - loss: 0.1048 - acc: 0.9567 - categorical_accuracy: 0.9110 - val_loss: 0.1039 - val_acc: 0.9587 - val_categorical_accuracy: 0.9200
# Epoch 24/200
# 66677/66677 [==============================] - 308s 5ms/step - loss: 0.1037 - acc: 0.9569 - categorical_accuracy: 0.9111 - val_loss: 0.1053 - val_acc: 0.9608 - val_categorical_accuracy: 0.9208
# Epoch 25/200
# 66677/66677 [==============================] - 308s 5ms/step - loss: 0.1011 - acc: 0.9578 - categorical_accuracy: 0.9130 - val_loss: 0.1018 - val_acc: 0.9593 - val_categorical_accuracy: 0.9196
# Epoch 26/200
# 66677/66677 [==============================] - 307s 5ms/step - loss: 0.1015 - acc: 0.9576 - categorical_accuracy: 0.9126 - val_loss: 0.1011 - val_acc: 0.9616 - val_categorical_accuracy: 0.9204
# Epoch 27/200
# 66677/66677 [==============================] - 307s 5ms/step - loss: 0.1011 - acc: 0.9582 - categorical_accuracy: 0.9140 - val_loss: 0.1009 - val_acc: 0.9600 - val_categorical_accuracy: 0.9171
# Epoch 28/200
# 66677/66677 [==============================] - 307s 5ms/step - loss: 0.1003 - acc: 0.9577 - categorical_accuracy: 0.9129 - val_loss: 0.1016 - val_acc: 0.9574 - val_categorical_accuracy: 0.9147
# Epoch 29/200
# 66677/66677 [==============================] - 307s 5ms/step - loss: 0.0982 - acc: 0.9594 - categorical_accuracy: 0.9159 - val_loss: 0.0989 - val_acc: 0.9583 - val_categorical_accuracy: 0.9163
# Epoch 30/200
# 66677/66677 [==============================] - 308s 5ms/step - loss: 0.0974 - acc: 0.9594 - categorical_accuracy: 0.9154 - val_loss: 0.1001 - val_acc: 0.9628 - val_categorical_accuracy: 0.9225
# Epoch 31/200
# 66677/66677 [==============================] - 307s 5ms/step - loss: 0.0975 - acc: 0.9594 - categorical_accuracy: 0.9154 - val_loss: 0.1030 - val_acc: 0.9591 - val_categorical_accuracy: 0.9184
# Epoch 32/200
# 66677/66677 [==============================] - 308s 5ms/step - loss: 0.0962 - acc: 0.9600 - categorical_accuracy: 0.9172 - val_loss: 0.1048 - val_acc: 0.9605 - val_categorical_accuracy: 0.9184
# Epoch 33/200
# 66677/66677 [==============================] - 308s 5ms/step - loss: 0.0955 - acc: 0.9600 - categorical_accuracy: 0.9167 - val_loss: 0.0981 - val_acc: 0.9618 - val_categorical_accuracy: 0.9208
# Epoch 34/200
# 66677/66677 [==============================] - 307s 5ms/step - loss: 0.0946 - acc: 0.9603 - categorical_accuracy: 0.9166 - val_loss: 0.1013 - val_acc: 0.9614 - val_categorical_accuracy: 0.9180
# Epoch 35/200
# 66677/66677 [==============================] - 308s 5ms/step - loss: 0.0950 - acc: 0.9602 - categorical_accuracy: 0.9173 - val_loss: 0.0993 - val_acc: 0.9628 - val_categorical_accuracy: 0.9212
# Epoch 36/200
# 66677/66677 [==============================] - 307s 5ms/step - loss: 0.0936 - acc: 0.9610 - categorical_accuracy: 0.9193 - val_loss: 0.1029 - val_acc: 0.9609 - val_categorical_accuracy: 0.9200
# Epoch 37/200
# 66677/66677 [==============================] - 308s 5ms/step - loss: 0.0960 - acc: 0.9596 - categorical_accuracy: 0.9161 - val_loss: 0.0978 - val_acc: 0.9624 - val_categorical_accuracy: 0.9225
# Epoch 38/200
# 66677/66677 [==============================] - 308s 5ms/step - loss: 0.0924 - acc: 0.9612 - categorical_accuracy: 0.9189 - val_loss: 0.0990 - val_acc: 0.9624 - val_categorical_accuracy: 0.9253
# Epoch 39/200
# 66677/66677 [==============================] - 307s 5ms/step - loss: 0.0926 - acc: 0.9608 - categorical_accuracy: 0.9185 - val_loss: 0.0963 - val_acc: 0.9644 - val_categorical_accuracy: 0.9249
# Epoch 40/200
# 66677/66677 [==============================] - 307s 5ms/step - loss: 0.0919 - acc: 0.9616 - categorical_accuracy: 0.9192 - val_loss: 0.0992 - val_acc: 0.9635 - val_categorical_accuracy: 0.9286
# Epoch 41/200
# 66677/66677 [==============================] - 307s 5ms/step - loss: 0.0891 - acc: 0.9629 - categorical_accuracy: 0.9226 - val_loss: 0.0962 - val_acc: 0.9653 - val_categorical_accuracy: 0.9323
# Epoch 42/200
# 66677/66677 [==============================] - 308s 5ms/step - loss: 0.0908 - acc: 0.9620 - categorical_accuracy: 0.9201 - val_loss: 0.0955 - val_acc: 0.9639 - val_categorical_accuracy: 0.9307
# Epoch 43/200
# 66677/66677 [==============================] - 307s 5ms/step - loss: 0.0915 - acc: 0.9614 - categorical_accuracy: 0.9194 - val_loss: 0.0955 - val_acc: 0.9632 - val_categorical_accuracy: 0.9278
# Epoch 44/200
# 66677/66677 [==============================] - 307s 5ms/step - loss: 0.0904 - acc: 0.9623 - categorical_accuracy: 0.9213 - val_loss: 0.1004 - val_acc: 0.9638 - val_categorical_accuracy: 0.9303
# Epoch 45/200
# 66677/66677 [==============================] - 307s 5ms/step - loss: 0.0903 - acc: 0.9625 - categorical_accuracy: 0.9210 - val_loss: 0.0975 - val_acc: 0.9639 - val_categorical_accuracy: 0.9299
# Epoch 46/200
# 66677/66677 [==============================] - 307s 5ms/step - loss: 0.0891 - acc: 0.9625 - categorical_accuracy: 0.9217 - val_loss: 0.0982 - val_acc: 0.9649 - val_categorical_accuracy: 0.9319
# Epoch 47/200
# 66677/66677 [==============================] - 308s 5ms/step - loss: 0.0878 - acc: 0.9631 - categorical_accuracy: 0.9235 - val_loss: 0.1006 - val_acc: 0.9642 - val_categorical_accuracy: 0.9311
# Epoch 48/200
# 66677/66677 [==============================] - 308s 5ms/step - loss: 0.0860 - acc: 0.9642 - categorical_accuracy: 0.9262 - val_loss: 0.0948 - val_acc: 0.9633 - val_categorical_accuracy: 0.9303
# Epoch 49/200
# 66677/66677 [==============================] - 308s 5ms/step - loss: 0.0880 - acc: 0.9634 - categorical_accuracy: 0.9238 - val_loss: 0.0930 - val_acc: 0.9643 - val_categorical_accuracy: 0.9307
# Epoch 50/200
# 66677/66677 [==============================] - 308s 5ms/step - loss: 0.0866 - acc: 0.9638 - categorical_accuracy: 0.9253 - val_loss: 0.0920 - val_acc: 0.9660 - val_categorical_accuracy: 0.9319
# Epoch 51/200
# 66677/66677 [==============================] - 283s 4ms/step - loss: 0.0878 - acc: 0.9633 - categorical_accuracy: 0.9238 - val_loss: 0.0930 - val_acc: 0.9672 - val_categorical_accuracy: 0.9368
# Epoch 52/200
# 66677/66677 [==============================] - 211s 3ms/step - loss: 0.0871 - acc: 0.9636 - categorical_accuracy: 0.9239 - val_loss: 0.0955 - val_acc: 0.9678 - val_categorical_accuracy: 0.9360
# Epoch 53/200
# 66677/66677 [==============================] - 212s 3ms/step - loss: 0.0852 - acc: 0.9647 - categorical_accuracy: 0.9262 - val_loss: 0.0926 - val_acc: 0.9668 - val_categorical_accuracy: 0.9348
# Epoch 54/200
# 66677/66677 [==============================] - 212s 3ms/step - loss: 0.0853 - acc: 0.9645 - categorical_accuracy: 0.9254 - val_loss: 0.0955 - val_acc: 0.9649 - val_categorical_accuracy: 0.9323
# Epoch 55/200
# 66677/66677 [==============================] - 212s 3ms/step - loss: 0.0874 - acc: 0.9640 - categorical_accuracy: 0.9247 - val_loss: 0.0932 - val_acc: 0.9670 - val_categorical_accuracy: 0.9356
# Epoch 56/200
# 66677/66677 [==============================] - 211s 3ms/step - loss: 0.0855 - acc: 0.9646 - categorical_accuracy: 0.9265 - val_loss: 0.0933 - val_acc: 0.9674 - val_categorical_accuracy: 0.9372
# Epoch 57/200
# 66677/66677 [==============================] - 211s 3ms/step - loss: 0.0847 - acc: 0.9643 - categorical_accuracy: 0.9255 - val_loss: 0.0962 - val_acc: 0.9635 - val_categorical_accuracy: 0.9258
# Epoch 58/200
# 66677/66677 [==============================] - 212s 3ms/step - loss: 0.0843 - acc: 0.9653 - categorical_accuracy: 0.9278 - val_loss: 0.0955 - val_acc: 0.9651 - val_categorical_accuracy: 0.9311
# Epoch 59/200
# 66677/66677 [==============================] - 212s 3ms/step - loss: 0.0859 - acc: 0.9643 - categorical_accuracy: 0.9253 - val_loss: 0.0937 - val_acc: 0.9683 - val_categorical_accuracy: 0.9364
# Epoch 60/200
# 66677/66677 [==============================] - 211s 3ms/step - loss: 0.0850 - acc: 0.9643 - categorical_accuracy: 0.9261 - val_loss: 0.0937 - val_acc: 0.9670 - val_categorical_accuracy: 0.9348
# Epoch 61/200
# 66677/66677 [==============================] - 211s 3ms/step - loss: 0.0843 - acc: 0.9645 - categorical_accuracy: 0.9258 - val_loss: 0.0945 - val_acc: 0.9670 - val_categorical_accuracy: 0.9344
# Epoch 62/200
# 66677/66677 [==============================] - 211s 3ms/step - loss: 0.0837 - acc: 0.9648 - categorical_accuracy: 0.9273 - val_loss: 0.1037 - val_acc: 0.9662 - val_categorical_accuracy: 0.9315
# Epoch 63/200
# 66677/66677 [==============================] - 211s 3ms/step - loss: 0.0821 - acc: 0.9658 - categorical_accuracy: 0.9282 - val_loss: 0.1027 - val_acc: 0.9672 - val_categorical_accuracy: 0.9352
# Epoch 64/200
# 66677/66677 [==============================] - 211s 3ms/step - loss: 0.0841 - acc: 0.9651 - categorical_accuracy: 0.9268 - val_loss: 0.0999 - val_acc: 0.9666 - val_categorical_accuracy: 0.9319
# Epoch 65/200
# 66677/66677 [==============================] - 211s 3ms/step - loss: 0.0831 - acc: 0.9656 - categorical_accuracy: 0.9281 - val_loss: 0.0928 - val_acc: 0.9701 - val_categorical_accuracy: 0.9409
# Epoch 66/200
# 66677/66677 [==============================] - 211s 3ms/step - loss: 0.0810 - acc: 0.9663 - categorical_accuracy: 0.9298 - val_loss: 0.0942 - val_acc: 0.9690 - val_categorical_accuracy: 0.9377
# Epoch 67/200
# 66677/66677 [==============================] - 212s 3ms/step - loss: 0.0827 - acc: 0.9657 - categorical_accuracy: 0.9286 - val_loss: 0.0984 - val_acc: 0.9678 - val_categorical_accuracy: 0.9356
# Epoch 68/200
# 66677/66677 [==============================] - 211s 3ms/step - loss: 0.0824 - acc: 0.9659 - categorical_accuracy: 0.9290 - val_loss: 0.1006 - val_acc: 0.9661 - val_categorical_accuracy: 0.9311
# Epoch 69/200
# 66677/66677 [==============================] - 211s 3ms/step - loss: 0.0802 - acc: 0.9665 - categorical_accuracy: 0.9303 - val_loss: 0.0982 - val_acc: 0.9671 - val_categorical_accuracy: 0.9344
# Epoch 70/200
# 66677/66677 [==============================] - 211s 3ms/step - loss: 0.0813 - acc: 0.9661 - categorical_accuracy: 0.9290 - val_loss: 0.0967 - val_acc: 0.9674 - val_categorical_accuracy: 0.9348
# Epoch 71/200
# 66677/66677 [==============================] - 211s 3ms/step - loss: 0.0823 - acc: 0.9660 - categorical_accuracy: 0.9292 - val_loss: 0.0941 - val_acc: 0.9662 - val_categorical_accuracy: 0.9336
# Epoch 72/200
# 66677/66677 [==============================] - 211s 3ms/step - loss: 0.0824 - acc: 0.9656 - categorical_accuracy: 0.9284 - val_loss: 0.0945 - val_acc: 0.9669 - val_categorical_accuracy: 0.9323
# Epoch 73/200
# 66677/66677 [==============================] - 211s 3ms/step - loss: 0.0815 - acc: 0.9658 - categorical_accuracy: 0.9289 - val_loss: 0.0954 - val_acc: 0.9683 - val_categorical_accuracy: 0.9360
# Epoch 74/200
# 66677/66677 [==============================] - 212s 3ms/step - loss: 0.0805 - acc: 0.9670 - categorical_accuracy: 0.9311 - val_loss: 0.0984 - val_acc: 0.9664 - val_categorical_accuracy: 0.9336
# Epoch 75/200
# 66677/66677 [==============================] - 211s 3ms/step - loss: 0.0797 - acc: 0.9670 - categorical_accuracy: 0.9310 - val_loss: 0.0944 - val_acc: 0.9684 - val_categorical_accuracy: 0.9360
# Epoch 76/200
# 66677/66677 [==============================] - 211s 3ms/step - loss: 0.0808 - acc: 0.9660 - categorical_accuracy: 0.9292 - val_loss: 0.0933 - val_acc: 0.9683 - val_categorical_accuracy: 0.9368
# Epoch 77/200
# 66677/66677 [==============================] - 211s 3ms/step - loss: 0.0802 - acc: 0.9669 - categorical_accuracy: 0.9310 - val_loss: 0.0926 - val_acc: 0.9677 - val_categorical_accuracy: 0.9336
# Epoch 78/200
# 66677/66677 [==============================] - 211s 3ms/step - loss: 0.0807 - acc: 0.9663 - categorical_accuracy: 0.9301 - val_loss: 0.0896 - val_acc: 0.9703 - val_categorical_accuracy: 0.9401
# Epoch 79/200
# 66677/66677 [==============================] - 211s 3ms/step - loss: 0.0783 - acc: 0.9671 - categorical_accuracy: 0.9319 - val_loss: 0.0959 - val_acc: 0.9690 - val_categorical_accuracy: 0.9377
# Epoch 80/200
# 66677/66677 [==============================] - 212s 3ms/step - loss: 0.0793 - acc: 0.9669 - categorical_accuracy: 0.9314 - val_loss: 0.1005 - val_acc: 0.9678 - val_categorical_accuracy: 0.9344
# Epoch 81/200
# 66677/66677 [==============================] - 211s 3ms/step - loss: 0.0789 - acc: 0.9670 - categorical_accuracy: 0.9317 - val_loss: 0.0972 - val_acc: 0.9691 - val_categorical_accuracy: 0.9372
# Epoch 82/200
# 66677/66677 [==============================] - 211s 3ms/step - loss: 0.0795 - acc: 0.9666 - categorical_accuracy: 0.9300 - val_loss: 0.0942 - val_acc: 0.9703 - val_categorical_accuracy: 0.9381
# Epoch 83/200
# 66677/66677 [==============================] - 211s 3ms/step - loss: 0.0792 - acc: 0.9669 - categorical_accuracy: 0.9313 - val_loss: 0.0952 - val_acc: 0.9684 - val_categorical_accuracy: 0.9340
# Epoch 84/200
# 66677/66677 [==============================] - 211s 3ms/step - loss: 0.0782 - acc: 0.9674 - categorical_accuracy: 0.9325 - val_loss: 0.0954 - val_acc: 0.9703 - val_categorical_accuracy: 0.9372
# Epoch 85/200
# 66677/66677 [==============================] - 211s 3ms/step - loss: 0.0794 - acc: 0.9673 - categorical_accuracy: 0.9315 - val_loss: 0.0952 - val_acc: 0.9710 - val_categorical_accuracy: 0.9393
# Epoch 86/200
# 66677/66677 [==============================] - 211s 3ms/step - loss: 0.0775 - acc: 0.9679 - categorical_accuracy: 0.9333 - val_loss: 0.0968 - val_acc: 0.9714 - val_categorical_accuracy: 0.9405
# Epoch 87/200
# 66677/66677 [==============================] - 211s 3ms/step - loss: 0.0784 - acc: 0.9671 - categorical_accuracy: 0.9324 - val_loss: 0.0909 - val_acc: 0.9722 - val_categorical_accuracy: 0.9434
# Epoch 88/200
# 66677/66677 [==============================] - 211s 3ms/step - loss: 0.0786 - acc: 0.9669 - categorical_accuracy: 0.9317 - val_loss: 0.0980 - val_acc: 0.9702 - val_categorical_accuracy: 0.9385
# Epoch 89/200
# 66677/66677 [==============================] - 211s 3ms/step - loss: 0.0792 - acc: 0.9669 - categorical_accuracy: 0.9314 - val_loss: 0.0961 - val_acc: 0.9690 - val_categorical_accuracy: 0.9372
# Epoch 90/200
# 66677/66677 [==============================] - 211s 3ms/step - loss: 0.0783 - acc: 0.9674 - categorical_accuracy: 0.9325 - val_loss: 0.0913 - val_acc: 0.9743 - val_categorical_accuracy: 0.9479
# Epoch 91/200
# 66677/66677 [==============================] - 211s 3ms/step - loss: 0.0792 - acc: 0.9668 - categorical_accuracy: 0.9308 - val_loss: 0.0976 - val_acc: 0.9711 - val_categorical_accuracy: 0.9413
# Epoch 92/200
# 66677/66677 [==============================] - 211s 3ms/step - loss: 0.0781 - acc: 0.9676 - categorical_accuracy: 0.9324 - val_loss: 0.0940 - val_acc: 0.9708 - val_categorical_accuracy: 0.9405
# Epoch 93/200
# 66677/66677 [==============================] - 212s 3ms/step - loss: 0.0766 - acc: 0.9678 - categorical_accuracy: 0.9332 - val_loss: 0.0928 - val_acc: 0.9714 - val_categorical_accuracy: 0.9422
# Epoch 94/200
# 66677/66677 [==============================] - 211s 3ms/step - loss: 0.0786 - acc: 0.9674 - categorical_accuracy: 0.9321 - val_loss: 0.0916 - val_acc: 0.9727 - val_categorical_accuracy: 0.9446
# Epoch 95/200
# 66677/66677 [==============================] - 211s 3ms/step - loss: 0.0775 - acc: 0.9681 - categorical_accuracy: 0.9333 - val_loss: 0.0986 - val_acc: 0.9710 - val_categorical_accuracy: 0.9413
# Epoch 96/200
# 66677/66677 [==============================] - 211s 3ms/step - loss: 0.0762 - acc: 0.9682 - categorical_accuracy: 0.9340 - val_loss: 0.0929 - val_acc: 0.9723 - val_categorical_accuracy: 0.9434
# Epoch 97/200
# 66677/66677 [==============================] - 211s 3ms/step - loss: 0.0777 - acc: 0.9676 - categorical_accuracy: 0.9329 - val_loss: 0.0933 - val_acc: 0.9696 - val_categorical_accuracy: 0.9389
# Epoch 98/200
# 66677/66677 [==============================] - 212s 3ms/step - loss: 0.0756 - acc: 0.9688 - categorical_accuracy: 0.9353 - val_loss: 0.0941 - val_acc: 0.9711 - val_categorical_accuracy: 0.9405
# Epoch 99/200
# 66677/66677 [==============================] - 212s 3ms/step - loss: 0.0778 - acc: 0.9677 - categorical_accuracy: 0.9328 - val_loss: 0.0917 - val_acc: 0.9719 - val_categorical_accuracy: 0.9426
# Epoch 100/200
# 66677/66677 [==============================] - 211s 3ms/step - loss: 0.0760 - acc: 0.9685 - categorical_accuracy: 0.9343 - val_loss: 0.0937 - val_acc: 0.9703 - val_categorical_accuracy: 0.9385
# Epoch 101/200
# 66677/66677 [==============================] - 211s 3ms/step - loss: 0.0751 - acc: 0.9690 - categorical_accuracy: 0.9353 - val_loss: 0.0910 - val_acc: 0.9720 - val_categorical_accuracy: 0.9422
# Epoch 102/200
# 66677/66677 [==============================] - 211s 3ms/step - loss: 0.0776 - acc: 0.9677 - categorical_accuracy: 0.9330 - val_loss: 0.0903 - val_acc: 0.9740 - val_categorical_accuracy: 0.9479
# Epoch 103/200
# 66677/66677 [==============================] - 212s 3ms/step - loss: 0.0755 - acc: 0.9688 - categorical_accuracy: 0.9347 - val_loss: 0.0907 - val_acc: 0.9727 - val_categorical_accuracy: 0.9450
# Epoch 104/200
# 66677/66677 [==============================] - 211s 3ms/step - loss: 0.0760 - acc: 0.9686 - categorical_accuracy: 0.9346 - val_loss: 0.0933 - val_acc: 0.9720 - val_categorical_accuracy: 0.9438
# Epoch 105/200
# 66677/66677 [==============================] - 211s 3ms/step - loss: 0.0768 - acc: 0.9680 - categorical_accuracy: 0.9333 - val_loss: 0.0899 - val_acc: 0.9736 - val_categorical_accuracy: 0.9463
# Epoch 106/200
# 66677/66677 [==============================] - 211s 3ms/step - loss: 0.0760 - acc: 0.9682 - categorical_accuracy: 0.9337 - val_loss: 0.0910 - val_acc: 0.9723 - val_categorical_accuracy: 0.9438
# Epoch 107/200
# 66677/66677 [==============================] - 212s 3ms/step - loss: 0.0772 - acc: 0.9677 - categorical_accuracy: 0.9330 - val_loss: 0.0906 - val_acc: 0.9713 - val_categorical_accuracy: 0.9413
# Epoch 108/200
# 66677/66677 [==============================] - 211s 3ms/step - loss: 0.0755 - acc: 0.9682 - categorical_accuracy: 0.9335 - val_loss: 0.0945 - val_acc: 0.9690 - val_categorical_accuracy: 0.9372
# Epoch 109/200
# 66677/66677 [==============================] - 211s 3ms/step - loss: 0.0757 - acc: 0.9685 - categorical_accuracy: 0.9347 - val_loss: 0.0898 - val_acc: 0.9726 - val_categorical_accuracy: 0.9446
# Epoch 110/200
# 66677/66677 [==============================] - 212s 3ms/step - loss: 0.0762 - acc: 0.9687 - categorical_accuracy: 0.9353 - val_loss: 0.0950 - val_acc: 0.9714 - val_categorical_accuracy: 0.9426
# Epoch 111/200
# 66677/66677 [==============================] - 212s 3ms/step - loss: 0.0757 - acc: 0.9688 - categorical_accuracy: 0.9354 - val_loss: 0.0921 - val_acc: 0.9718 - val_categorical_accuracy: 0.9422
# Epoch 112/200
# 66677/66677 [==============================] - 211s 3ms/step - loss: 0.0773 - acc: 0.9682 - categorical_accuracy: 0.9343 - val_loss: 0.0937 - val_acc: 0.9696 - val_categorical_accuracy: 0.9372
# Epoch 113/200
# 66677/66677 [==============================] - 211s 3ms/step - loss: 0.0750 - acc: 0.9690 - categorical_accuracy: 0.9353 - val_loss: 0.0909 - val_acc: 0.9728 - val_categorical_accuracy: 0.9446
# Epoch 114/200
# 66677/66677 [==============================] - 211s 3ms/step - loss: 0.0754 - acc: 0.9689 - categorical_accuracy: 0.9352 - val_loss: 0.0914 - val_acc: 0.9726 - val_categorical_accuracy: 0.9442
# Epoch 115/200
# 66677/66677 [==============================] - 210s 3ms/step - loss: 0.0756 - acc: 0.9684 - categorical_accuracy: 0.9346 - val_loss: 0.0915 - val_acc: 0.9728 - val_categorical_accuracy: 0.9438
# Epoch 116/200
# 66677/66677 [==============================] - 210s 3ms/step - loss: 0.0751 - acc: 0.9690 - categorical_accuracy: 0.9353 - val_loss: 0.0930 - val_acc: 0.9727 - val_categorical_accuracy: 0.9438
# Epoch 117/200
# 66677/66677 [==============================] - 210s 3ms/step - loss: 0.0745 - acc: 0.9689 - categorical_accuracy: 0.9355 - val_loss: 0.0901 - val_acc: 0.9750 - val_categorical_accuracy: 0.9479
# Epoch 118/200
# 66677/66677 [==============================] - 209s 3ms/step - loss: 0.0744 - acc: 0.9693 - categorical_accuracy: 0.9360 - val_loss: 0.0901 - val_acc: 0.9735 - val_categorical_accuracy: 0.9467
# Epoch 119/200
# 66677/66677 [==============================] - 209s 3ms/step - loss: 0.0766 - acc: 0.9683 - categorical_accuracy: 0.9341 - val_loss: 0.0895 - val_acc: 0.9710 - val_categorical_accuracy: 0.9409
# Epoch 120/200
# 66677/66677 [==============================] - 209s 3ms/step - loss: 0.0751 - acc: 0.9688 - categorical_accuracy: 0.9356 - val_loss: 0.0905 - val_acc: 0.9734 - val_categorical_accuracy: 0.9467
# Epoch 121/200
# 66677/66677 [==============================] - 208s 3ms/step - loss: 0.0767 - acc: 0.9684 - categorical_accuracy: 0.9337 - val_loss: 0.0933 - val_acc: 0.9708 - val_categorical_accuracy: 0.9413
# Epoch 122/200
# 66677/66677 [==============================] - 209s 3ms/step - loss: 0.0740 - acc: 0.9696 - categorical_accuracy: 0.9372 - val_loss: 0.0926 - val_acc: 0.9729 - val_categorical_accuracy: 0.9450
# Epoch 123/200
# 66677/66677 [==============================] - 209s 3ms/step - loss: 0.0755 - acc: 0.9685 - categorical_accuracy: 0.9344 - val_loss: 0.0865 - val_acc: 0.9747 - val_categorical_accuracy: 0.9479
# Epoch 124/200
# 66677/66677 [==============================] - 208s 3ms/step - loss: 0.0742 - acc: 0.9692 - categorical_accuracy: 0.9359 - val_loss: 0.0915 - val_acc: 0.9709 - val_categorical_accuracy: 0.9413
# Epoch 125/200
# 66677/66677 [==============================] - 209s 3ms/step - loss: 0.0737 - acc: 0.9692 - categorical_accuracy: 0.9363 - val_loss: 0.0908 - val_acc: 0.9728 - val_categorical_accuracy: 0.9463
# Epoch 126/200
# 66677/66677 [==============================] - 208s 3ms/step - loss: 0.0724 - acc: 0.9700 - categorical_accuracy: 0.9373 - val_loss: 0.0890 - val_acc: 0.9718 - val_categorical_accuracy: 0.9430
# Epoch 127/200
# 66677/66677 [==============================] - 208s 3ms/step - loss: 0.0741 - acc: 0.9687 - categorical_accuracy: 0.9352 - val_loss: 0.0959 - val_acc: 0.9708 - val_categorical_accuracy: 0.9413
# Epoch 128/200
# 66677/66677 [==============================] - 208s 3ms/step - loss: 0.0749 - acc: 0.9689 - categorical_accuracy: 0.9354 - val_loss: 0.0996 - val_acc: 0.9700 - val_categorical_accuracy: 0.9393
# Epoch 129/200
# 66677/66677 [==============================] - 208s 3ms/step - loss: 0.0748 - acc: 0.9690 - categorical_accuracy: 0.9363 - val_loss: 0.0963 - val_acc: 0.9706 - val_categorical_accuracy: 0.9409
# Epoch 130/200
# 66677/66677 [==============================] - 208s 3ms/step - loss: 0.0738 - acc: 0.9693 - categorical_accuracy: 0.9370 - val_loss: 0.0948 - val_acc: 0.9734 - val_categorical_accuracy: 0.9463
# Epoch 131/200
# 66677/66677 [==============================] - 208s 3ms/step - loss: 0.0744 - acc: 0.9694 - categorical_accuracy: 0.9363 - val_loss: 0.0942 - val_acc: 0.9735 - val_categorical_accuracy: 0.9467
# Epoch 132/200
# 66677/66677 [==============================] - 208s 3ms/step - loss: 0.0750 - acc: 0.9689 - categorical_accuracy: 0.9348 - val_loss: 0.0908 - val_acc: 0.9720 - val_categorical_accuracy: 0.9442
# Epoch 133/200
# 66677/66677 [==============================] - 208s 3ms/step - loss: 0.0752 - acc: 0.9692 - categorical_accuracy: 0.9352 - val_loss: 0.0948 - val_acc: 0.9718 - val_categorical_accuracy: 0.9434
# Epoch 134/200
# 66677/66677 [==============================] - 209s 3ms/step - loss: 0.0731 - acc: 0.9698 - categorical_accuracy: 0.9373 - val_loss: 0.0941 - val_acc: 0.9724 - val_categorical_accuracy: 0.9450
# Epoch 135/200
# 66677/66677 [==============================] - 208s 3ms/step - loss: 0.0730 - acc: 0.9697 - categorical_accuracy: 0.9365 - val_loss: 0.0890 - val_acc: 0.9736 - val_categorical_accuracy: 0.9467
# Epoch 136/200
# 66677/66677 [==============================] - 208s 3ms/step - loss: 0.0760 - acc: 0.9687 - categorical_accuracy: 0.9347 - val_loss: 0.0955 - val_acc: 0.9707 - val_categorical_accuracy: 0.9409
# Epoch 137/200
# 66677/66677 [==============================] - 208s 3ms/step - loss: 0.0724 - acc: 0.9701 - categorical_accuracy: 0.9376 - val_loss: 0.0912 - val_acc: 0.9744 - val_categorical_accuracy: 0.9495
# Epoch 138/200
# 66677/66677 [==============================] - 208s 3ms/step - loss: 0.0746 - acc: 0.9691 - categorical_accuracy: 0.9355 - val_loss: 0.0929 - val_acc: 0.9734 - val_categorical_accuracy: 0.9467
# Epoch 139/200
# 66677/66677 [==============================] - 208s 3ms/step - loss: 0.0730 - acc: 0.9694 - categorical_accuracy: 0.9357 - val_loss: 0.0875 - val_acc: 0.9733 - val_categorical_accuracy: 0.9471
# Epoch 140/200
# 66677/66677 [==============================] - 209s 3ms/step - loss: 0.0740 - acc: 0.9698 - categorical_accuracy: 0.9377 - val_loss: 0.0900 - val_acc: 0.9750 - val_categorical_accuracy: 0.9508
# Epoch 141/200
# 66677/66677 [==============================] - 235s 4ms/step - loss: 0.0727 - acc: 0.9702 - categorical_accuracy: 0.9376 - val_loss: 0.0946 - val_acc: 0.9718 - val_categorical_accuracy: 0.9438
# Epoch 142/200
# 66677/66677 [==============================] - 207s 3ms/step - loss: 0.0732 - acc: 0.9694 - categorical_accuracy: 0.9360 - val_loss: 0.0913 - val_acc: 0.9721 - val_categorical_accuracy: 0.9450
# Epoch 143/200
# 66677/66677 [==============================] - 207s 3ms/step - loss: 0.0716 - acc: 0.9703 - categorical_accuracy: 0.9382 - val_loss: 0.0934 - val_acc: 0.9734 - val_categorical_accuracy: 0.9471
# Epoch 144/200
# 66677/66677 [==============================] - 207s 3ms/step - loss: 0.0734 - acc: 0.9697 - categorical_accuracy: 0.9371 - val_loss: 0.0962 - val_acc: 0.9725 - val_categorical_accuracy: 0.9438
# Epoch 145/200
# 66677/66677 [==============================] - 207s 3ms/step - loss: 0.0727 - acc: 0.9694 - categorical_accuracy: 0.9367 - val_loss: 0.0921 - val_acc: 0.9755 - val_categorical_accuracy: 0.9504
# Epoch 146/200
# 66677/66677 [==============================] - 207s 3ms/step - loss: 0.0728 - acc: 0.9697 - categorical_accuracy: 0.9370 - val_loss: 0.0947 - val_acc: 0.9732 - val_categorical_accuracy: 0.9454
# Epoch 147/200
# 66677/66677 [==============================] - 207s 3ms/step - loss: 0.0697 - acc: 0.9711 - categorical_accuracy: 0.9398 - val_loss: 0.0946 - val_acc: 0.9727 - val_categorical_accuracy: 0.9438
# Epoch 148/200
# 66677/66677 [==============================] - 206s 3ms/step - loss: 0.0730 - acc: 0.9697 - categorical_accuracy: 0.9372 - val_loss: 0.0980 - val_acc: 0.9712 - val_categorical_accuracy: 0.9418
# Epoch 149/200
# 66677/66677 [==============================] - 207s 3ms/step - loss: 0.0718 - acc: 0.9702 - categorical_accuracy: 0.9376 - val_loss: 0.0986 - val_acc: 0.9721 - val_categorical_accuracy: 0.9426
# Epoch 150/200
# 66677/66677 [==============================] - 207s 3ms/step - loss: 0.0725 - acc: 0.9702 - categorical_accuracy: 0.9380 - val_loss: 0.0941 - val_acc: 0.9735 - val_categorical_accuracy: 0.9446
# Epoch 151/200
# 66677/66677 [==============================] - 207s 3ms/step - loss: 0.0722 - acc: 0.9707 - categorical_accuracy: 0.9387 - val_loss: 0.0935 - val_acc: 0.9728 - val_categorical_accuracy: 0.9438
# Epoch 152/200
# 66677/66677 [==============================] - 207s 3ms/step - loss: 0.0715 - acc: 0.9709 - categorical_accuracy: 0.9395 - val_loss: 0.0943 - val_acc: 0.9726 - val_categorical_accuracy: 0.9426
# Epoch 153/200
# 66677/66677 [==============================] - 206s 3ms/step - loss: 0.0715 - acc: 0.9702 - categorical_accuracy: 0.9382 - val_loss: 0.0958 - val_acc: 0.9729 - val_categorical_accuracy: 0.9467
# Epoch 154/200
# 66677/66677 [==============================] - 207s 3ms/step - loss: 0.0725 - acc: 0.9703 - categorical_accuracy: 0.9383 - val_loss: 0.0960 - val_acc: 0.9727 - val_categorical_accuracy: 0.9418
# Epoch 155/200
# 66677/66677 [==============================] - 207s 3ms/step - loss: 0.0722 - acc: 0.9701 - categorical_accuracy: 0.9377 - val_loss: 0.0954 - val_acc: 0.9736 - val_categorical_accuracy: 0.9454
# Epoch 156/200
# 66677/66677 [==============================] - 207s 3ms/step - loss: 0.0730 - acc: 0.9694 - categorical_accuracy: 0.9363 - val_loss: 0.0951 - val_acc: 0.9706 - val_categorical_accuracy: 0.9401
# Epoch 157/200
# 66677/66677 [==============================] - 207s 3ms/step - loss: 0.0719 - acc: 0.9702 - categorical_accuracy: 0.9376 - val_loss: 0.0960 - val_acc: 0.9731 - val_categorical_accuracy: 0.9446
# Epoch 158/200
# 66677/66677 [==============================] - 207s 3ms/step - loss: 0.0724 - acc: 0.9698 - categorical_accuracy: 0.9373 - val_loss: 0.0923 - val_acc: 0.9726 - val_categorical_accuracy: 0.9434
# Epoch 159/200
# 66677/66677 [==============================] - 207s 3ms/step - loss: 0.0727 - acc: 0.9700 - categorical_accuracy: 0.9371 - val_loss: 0.0922 - val_acc: 0.9735 - val_categorical_accuracy: 0.9475
# Epoch 160/200
# 66677/66677 [==============================] - 207s 3ms/step - loss: 0.0722 - acc: 0.9700 - categorical_accuracy: 0.9378 - val_loss: 0.0960 - val_acc: 0.9705 - val_categorical_accuracy: 0.9413
# Epoch 161/200
# 66677/66677 [==============================] - 207s 3ms/step - loss: 0.0712 - acc: 0.9703 - categorical_accuracy: 0.9384 - val_loss: 0.0962 - val_acc: 0.9730 - val_categorical_accuracy: 0.9463
# Epoch 162/200
# 66677/66677 [==============================] - 207s 3ms/step - loss: 0.0717 - acc: 0.9706 - categorical_accuracy: 0.9388 - val_loss: 0.0932 - val_acc: 0.9735 - val_categorical_accuracy: 0.9463
# Epoch 163/200
# 66677/66677 [==============================] - 207s 3ms/step - loss: 0.0707 - acc: 0.9708 - categorical_accuracy: 0.9396 - val_loss: 0.0958 - val_acc: 0.9742 - val_categorical_accuracy: 0.9491
# Epoch 164/200
# 66677/66677 [==============================] - 206s 3ms/step - loss: 0.0711 - acc: 0.9703 - categorical_accuracy: 0.9387 - val_loss: 0.0956 - val_acc: 0.9726 - val_categorical_accuracy: 0.9434
# Epoch 165/200
# 66677/66677 [==============================] - 207s 3ms/step - loss: 0.0717 - acc: 0.9706 - categorical_accuracy: 0.9393 - val_loss: 0.0968 - val_acc: 0.9730 - val_categorical_accuracy: 0.9471
# Epoch 166/200
# 66677/66677 [==============================] - 206s 3ms/step - loss: 0.0718 - acc: 0.9707 - categorical_accuracy: 0.9387 - val_loss: 0.0943 - val_acc: 0.9726 - val_categorical_accuracy: 0.9442
# Epoch 167/200
# 66677/66677 [==============================] - 206s 3ms/step - loss: 0.0721 - acc: 0.9699 - categorical_accuracy: 0.9380 - val_loss: 0.0949 - val_acc: 0.9741 - val_categorical_accuracy: 0.9491
# Epoch 168/200
# 66677/66677 [==============================] - 207s 3ms/step - loss: 0.0709 - acc: 0.9708 - categorical_accuracy: 0.9395 - val_loss: 0.0932 - val_acc: 0.9741 - val_categorical_accuracy: 0.9483
# Epoch 169/200
# 66677/66677 [==============================] - 206s 3ms/step - loss: 0.0726 - acc: 0.9702 - categorical_accuracy: 0.9379 - val_loss: 0.0942 - val_acc: 0.9748 - val_categorical_accuracy: 0.9487
# Epoch 170/200
# 66677/66677 [==============================] - 207s 3ms/step - loss: 0.0697 - acc: 0.9709 - categorical_accuracy: 0.9401 - val_loss: 0.0964 - val_acc: 0.9755 - val_categorical_accuracy: 0.9516
# Epoch 171/200
# 66677/66677 [==============================] - 207s 3ms/step - loss: 0.0696 - acc: 0.9715 - categorical_accuracy: 0.9403 - val_loss: 0.0919 - val_acc: 0.9739 - val_categorical_accuracy: 0.9475
# Epoch 172/200
# 66677/66677 [==============================] - 207s 3ms/step - loss: 0.0704 - acc: 0.9708 - categorical_accuracy: 0.9391 - val_loss: 0.0925 - val_acc: 0.9728 - val_categorical_accuracy: 0.9442
# Epoch 173/200
# 66677/66677 [==============================] - 206s 3ms/step - loss: 0.0702 - acc: 0.9708 - categorical_accuracy: 0.9388 - val_loss: 0.0979 - val_acc: 0.9757 - val_categorical_accuracy: 0.9500
# Epoch 174/200
# 66677/66677 [==============================] - 207s 3ms/step - loss: 0.0708 - acc: 0.9708 - categorical_accuracy: 0.9392 - val_loss: 0.0963 - val_acc: 0.9734 - val_categorical_accuracy: 0.9442
# Epoch 175/200
# 66677/66677 [==============================] - 207s 3ms/step - loss: 0.0725 - acc: 0.9698 - categorical_accuracy: 0.9370 - val_loss: 0.0949 - val_acc: 0.9731 - val_categorical_accuracy: 0.9442
# Epoch 176/200
# 66677/66677 [==============================] - 206s 3ms/step - loss: 0.0692 - acc: 0.9713 - categorical_accuracy: 0.9403 - val_loss: 0.0928 - val_acc: 0.9740 - val_categorical_accuracy: 0.9475
# Epoch 177/200
# 66677/66677 [==============================] - 207s 3ms/step - loss: 0.0708 - acc: 0.9706 - categorical_accuracy: 0.9389 - val_loss: 0.0916 - val_acc: 0.9744 - val_categorical_accuracy: 0.9479
# Epoch 178/200
# 66677/66677 [==============================] - 207s 3ms/step - loss: 0.0723 - acc: 0.9704 - categorical_accuracy: 0.9382 - val_loss: 0.0906 - val_acc: 0.9737 - val_categorical_accuracy: 0.9467
# Epoch 179/200
# 66677/66677 [==============================] - 207s 3ms/step - loss: 0.0708 - acc: 0.9708 - categorical_accuracy: 0.9393 - val_loss: 0.0951 - val_acc: 0.9732 - val_categorical_accuracy: 0.9467
# Epoch 180/200
# 66677/66677 [==============================] - 207s 3ms/step - loss: 0.0709 - acc: 0.9703 - categorical_accuracy: 0.9384 - val_loss: 0.0948 - val_acc: 0.9745 - val_categorical_accuracy: 0.9504
# Epoch 181/200
# 66677/66677 [==============================] - 207s 3ms/step - loss: 0.0718 - acc: 0.9703 - categorical_accuracy: 0.9383 - val_loss: 0.0964 - val_acc: 0.9730 - val_categorical_accuracy: 0.9463
# Epoch 182/200
# 66677/66677 [==============================] - 206s 3ms/step - loss: 0.0699 - acc: 0.9711 - categorical_accuracy: 0.9399 - val_loss: 0.0950 - val_acc: 0.9745 - val_categorical_accuracy: 0.9483
# Epoch 183/200
# 66677/66677 [==============================] - 207s 3ms/step - loss: 0.0693 - acc: 0.9708 - categorical_accuracy: 0.9389 - val_loss: 0.0946 - val_acc: 0.9736 - val_categorical_accuracy: 0.9459
# Epoch 184/200
# 66677/66677 [==============================] - 207s 3ms/step - loss: 0.0701 - acc: 0.9710 - categorical_accuracy: 0.9399 - val_loss: 0.0922 - val_acc: 0.9740 - val_categorical_accuracy: 0.9471
# Epoch 185/200
# 66677/66677 [==============================] - 207s 3ms/step - loss: 0.0710 - acc: 0.9707 - categorical_accuracy: 0.9386 - val_loss: 0.0919 - val_acc: 0.9751 - val_categorical_accuracy: 0.9491
# Epoch 186/200
# 66677/66677 [==============================] - 219s 3ms/step - loss: 0.0694 - acc: 0.9712 - categorical_accuracy: 0.9405 - val_loss: 0.0911 - val_acc: 0.9732 - val_categorical_accuracy: 0.9442
# Epoch 187/200
# 66677/66677 [==============================] - 306s 5ms/step - loss: 0.0683 - acc: 0.9717 - categorical_accuracy: 0.9406 - val_loss: 0.0932 - val_acc: 0.9753 - val_categorical_accuracy: 0.9495
# Epoch 188/200
# 66677/66677 [==============================] - 368s 6ms/step - loss: 0.0712 - acc: 0.9712 - categorical_accuracy: 0.9395 - val_loss: 0.0978 - val_acc: 0.9728 - val_categorical_accuracy: 0.9450
# Epoch 189/200
# 66677/66677 [==============================] - 367s 5ms/step - loss: 0.0702 - acc: 0.9708 - categorical_accuracy: 0.9395 - val_loss: 0.0912 - val_acc: 0.9735 - val_categorical_accuracy: 0.9483
# Epoch 190/200
# 66677/66677 [==============================] - 367s 6ms/step - loss: 0.0717 - acc: 0.9708 - categorical_accuracy: 0.9392 - val_loss: 0.0955 - val_acc: 0.9743 - val_categorical_accuracy: 0.9487
# Epoch 191/200
# 66677/66677 [==============================] - 367s 5ms/step - loss: 0.0697 - acc: 0.9710 - categorical_accuracy: 0.9397 - val_loss: 0.0916 - val_acc: 0.9736 - val_categorical_accuracy: 0.9467
# Epoch 192/200
# 66677/66677 [==============================] - 368s 6ms/step - loss: 0.0705 - acc: 0.9709 - categorical_accuracy: 0.9395 - val_loss: 0.0943 - val_acc: 0.9743 - val_categorical_accuracy: 0.9479
# Epoch 193/200
# 66677/66677 [==============================] - 257s 4ms/step - loss: 0.0688 - acc: 0.9716 - categorical_accuracy: 0.9405 - val_loss: 0.0957 - val_acc: 0.9735 - val_categorical_accuracy: 0.9467
# Epoch 194/200
# 66677/66677 [==============================] - 262s 4ms/step - loss: 0.0680 - acc: 0.9714 - categorical_accuracy: 0.9408 - val_loss: 0.0963 - val_acc: 0.9728 - val_categorical_accuracy: 0.9430
# Epoch 195/200
# 66677/66677 [==============================] - 367s 6ms/step - loss: 0.0690 - acc: 0.9709 - categorical_accuracy: 0.9398 - val_loss: 0.0951 - val_acc: 0.9732 - val_categorical_accuracy: 0.9463
# Epoch 196/200
# 66677/66677 [==============================] - 368s 6ms/step - loss: 0.0702 - acc: 0.9708 - categorical_accuracy: 0.9392 - val_loss: 0.0946 - val_acc: 0.9737 - val_categorical_accuracy: 0.9454
# Epoch 197/200
# 66677/66677 [==============================] - 368s 6ms/step - loss: 0.0705 - acc: 0.9712 - categorical_accuracy: 0.9399 - val_loss: 0.0934 - val_acc: 0.9744 - val_categorical_accuracy: 0.9483
# Epoch 198/200
# 66677/66677 [==============================] - 367s 6ms/step - loss: 0.0692 - acc: 0.9716 - categorical_accuracy: 0.9410 - val_loss: 0.0917 - val_acc: 0.9748 - val_categorical_accuracy: 0.9500
# Epoch 199/200
# 66677/66677 [==============================] - 367s 6ms/step - loss: 0.0692 - acc: 0.9713 - categorical_accuracy: 0.9404 - val_loss: 0.0976 - val_acc: 0.9743 - val_categorical_accuracy: 0.9487
# Epoch 200/200
# 66677/66677 [==============================] - 309s 5ms/step - loss: 0.0706 - acc: 0.9710 - categorical_accuracy: 0.9393 - val_loss: 0.0941 - val_acc: 0.9742 - val_categorical_accuracy: 0.9483

# %%
model.save('my_model_try_128_200epoch.h5')

# %%
prediction = model.predict([X_test_q1, X_test_q2, np.array(feature_test)])

# %% [markdown]
# # Evaluation

# %%
# Compute the prediction and true value
correct = {0: 0, 1:0, 2: 0, 3: 0}
pred_count = {0: 0, 1:0, 2: 0, 3: 0}
true_count = {0: 0, 1:0, 2: 0, 3: 0}
prediction2 = np.argmax(prediction, axis=-1)
y_train2 = np.argmax(y_test, axis=-1)
for p, t in zip(prediction2, y_train2):
    if p == t:
        correct[p] += 1
    pred_count[p] += 1
    true_count[t] += 1

# %%
pred_count
# Out:
# {0: 41, 1: 195, 2: 409, 3: 1793}

# %%
true_count
# Out:
# {0: 46, 1: 187, 2: 413, 3: 1792}

# %%
# Precision, Recall, F1 score
for k in correct:
    c, t, p = correct[k], true_count[k], pred_count[k]
    pre = c / p
    rec = c / t
    f1 = 2 * pre * rec / (pre + rec)
    print("precision at {}: {}".format(k, pre))
    print("recall at {}: {}".format(k, rec))
    print("f1 at {}: {}".format(k, f1))
# Out:
# precision at 0: 0.8048780487804879
# recall at 0: 0.717391304347826
# f1 at 0: 0.7586206896551724
# precision at 1: 0.8102564102564103
# recall at 1: 0.8449197860962567
# f1 at 1: 0.8272251308900525
# precision at 2: 0.9242053789731052
# recall at 2: 0.9152542372881356
# f1 at 2: 0.9197080291970803
# precision at 3: 0.9721137757947574
# recall at 3: 0.97265625
# f1 at 3: 0.9723849372384937

# %% [markdown]
# # Prediction

# %%
# Input test data and transform it into dictionary
testData_Heading = pd.read_csv("/home/students/y2886wan/Data/test_data.csv")
testData = pd.merge(testData_Heading, trainData_Bodies, how='left', on='Body ID')
testData['Headline'] = testData['Headline'].apply(lambda x: str(x))
testData['articleBody'] = testData['articleBody'].apply(lambda x: str(x))

# Generating the features for test data 
test_headling = []
process_questions(test_headling, testData.Headline, 'test_headling', testData)
test_bodies = []
process_questions(test_bodies, testData.articleBody, 'testData_bodies', testData)

### overlap
cnt_t = get_pairwise_word_to_doc_freq(test_headling, test_bodies)
overlap_features_t = get_pairwise_overlap_features(test_headling, test_bodies, cnt_t)

### refuting
refuting_feature_t = refuting_features(test_headling, test_bodies)

### polarity
polarity_feature_t = polarity_features(test_headling, test_bodies)
polarity_t = [i.tolist() for i in polarity_feature_t]


features_t = [[x+y+z] for x,y,z in zip(overlap_features_t, refuting_feature_t, polarity_t)]
feature_t = [x[0] for x in features_t]



# Tokenizer
word_seq_t = test_headling + test_bodies
word_seq_t = [' '.join(word_tokenize(q)[:MAX_SENT_LEN_2]) for q in word_seq_t]
tokenizer_t = Tokenizer(num_words=MAX_VOCAB_SIZE, filters='!"#$%&()*+,-./:;<=>@[\\]^_`{|}~\t\n')
tokenizer_t.fit_on_texts(word_seq_t)

# Transform test data into matrix using dictionary
XT = tokenizer_t.texts_to_sequences(word_seq_t)
XT = pad_sequences(XT, maxlen=MAX_SENT_LEN_2, padding='post', truncating='post')

X_q1_t = XT[:len(XT)//2]
X_q2_t = XT[len(XT)//2:]
X_q1_t = np.delete(X_q1_t, range(MAX_SENT_LEN_1, MAX_SENT_LEN_2), axis = 1)
del XT
# Out:
# 6270it [00:01, 4538.06it/s]
# 6270it [00:18, 342.59it/s]

# %%
# Model prediction
prediction2 = model.predict(x = [X_q1_t, X_q2_t, np.array(feature_t)])

# %%
# Choosing the highest probability position of each vector
predicted = [[np.argmax(x)] for x in prediction2]

# %%
# transform all position into string (four classes) 
wordstance=[]
for i in predicted:
    if i==[0]:
        wordstance.append("disagree")
    if i==[1]:
        wordstance.append("agree")
    if i==[2]:
        wordstance.append("discuss")
    if i==[3]:
        wordstance.append("unrelated")
wordstance
# Out:
# ['discuss',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'agree',
#  'unrelated',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'agree',
#  'agree',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'agree',
#  'agree',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'agree',
#  'unrelated',
#  'agree',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'agree',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'discuss',
#  'discuss',
#  'disagree',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'discuss',
#  'agree',
#  'unrelated',
#  'agree',
#  'discuss',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'discuss',
#  'agree',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'discuss',
#  'agree',
#  'unrelated',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'agree',
#  'agree',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'discuss',
#  'agree',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'agree',
#  'discuss',
#  'disagree',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'disagree',
#  'discuss',
#  'unrelated',
#  'discuss',
#  'agree',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'agree',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'agree',
#  'agree',
#  'discuss',
#  'agree',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'agree',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'agree',
#  'unrelated',
#  'unrelated',
#  'disagree',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'disagree',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'agree',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'agree',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'agree',
#  'discuss',
#  'discuss',
#  'discuss',
#  'discuss',
#  'agree',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'agree',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'discuss',
#  'discuss',
#  'disagree',
#  'discuss',
#  'unrelated',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'agree',
#  'discuss',
#  'unrelated',
#  'agree',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'agree',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'agree',
#  'unrelated',
#  'unrelated',
#  'agree',
#  'unrelated',
#  'agree',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'discuss',
#  'agree',
#  'unrelated',
#  'unrelated',
#  'agree',
#  'disagree',
#  'unrelated',
#  'agree',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'agree',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'agree',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'agree',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'disagree',
#  'agree',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'agree',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'agree',
#  'discuss',
#  'unrelated',
#  'discuss',
#  'agree',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'agree',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'disagree',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'disagree',
#  'disagree',
#  'agree',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'discuss',
#  'agree',
#  'unrelated',
#  'unrelated',
#  'agree',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'discuss',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'agree',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'agree',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'discuss',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'agree',
#  'unrelated',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'discuss',
#  'agree',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'agree',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'agree',
#  'discuss',
#  'unrelated',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'agree',
#  'agree',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'agree',
#  'agree',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'agree',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'agree',
#  'unrelated',
#  'unrelated',
#  'agree',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'agree',
#  'discuss',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'discuss',
#  'discuss',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'agree',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'discuss',
#  'agree',
#  'discuss',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'agree',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'discuss',
#  'agree',
#  'unrelated',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'disagree',
#  'unrelated',
#  'agree',
#  'discuss',
#  'disagree',
#  'unrelated',
#  'disagree',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'disagree',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'discuss',
#  'agree',
#  'unrelated',
#  'discuss',
#  'discuss',
#  'agree',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'agree',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'agree',
#  'unrelated',
#  'unrelated',
#  'agree',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'agree',
#  'unrelated',
#  'disagree',
#  'agree',
#  'unrelated',
#  'discuss',
#  'agree',
#  'discuss',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'agree',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'agree',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'agree',
#  'unrelated',
#  'agree',
#  'unrelated',
#  'agree',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'discuss',
#  'agree',
#  'disagree',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'agree',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'agree',
#  'agree',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'agree',
#  'agree',
#  'unrelated',
#  'unrelated',
#  'agree',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'agree',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'agree',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'agree',
#  'agree',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'agree',
#  'unrelated',
#  'discuss',
#  'agree',
#  'unrelated',
#  'agree',
#  'agree',
#  'discuss',
#  'discuss',
#  'discuss',
#  'discuss',
#  'discuss',
#  'agree',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'agree',
#  'agree',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'agree',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'agree',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'agree',
#  'unrelated',
#  'discuss',
#  'agree',
#  'discuss',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'agree',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'agree',
#  'unrelated',
#  'agree',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'agree',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'agree',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'agree',
#  'discuss',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'discuss',
#  'discuss',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'discuss',
#  'unrelated',
#  'agree',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'agree',
#  'discuss',
#  'unrelated',
#  'discuss',
#  'agree',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'discuss',
#  'unrelated',
#  'discuss',
#  'agree',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'unrelated',
#  'agree',
#  'unrelated',
#  ...]

# %%
# Prediction save as CSV file
wordseries=pd.Series(wordstance) # all stance
testData = pd.read_csv("/home/students/y2886wan/Data/test_data.csv")
testData['Stance'] = wordseries.values
results = testData.to_csv('answer.csv',index=False, encoding='utf-8')
